# %% [markdown]
# Nessa seção vamos apresentar, explicar e executar um código em python, utilizando o Google Colab para treinar um modelo de uma rede neural multi-camadas (multilayer perceptron).
#
# A ideia é receber um conjunto de dados, montar a topologia da rede, aprender a utilizar biblioteca de criação de Multilayer Perceptron, realizar o treinamento e avaliar a rede treinada

# %%
# Preparação de dados
# Primeiro, devemos importar as bibliotecas necessárias

# Lib de Análise de Dados Pandas:
import pandas as pd
# Lib de computação científica:
import numpy as np

# %%
# Usando o pandas, podemos baixar o conjunto de dados de um determinado URL
# e convertê-lo em um conjunto de dados:

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
#new_names = ['sepal_length','sepal_width','petal_length','petal_width','iris_class']
new_names = ['altura_sépala','largula_sépala','altura_pétala','largura_pétala','tipo_de_iris']
dataset = pd.read_csv(url, names=new_names, skiprows=0, delimiter=',')
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   altura_sépala   150 non-null    float64
#  1   largula_sépala  150 non-null    float64
#  2   altura_pétala   150 non-null    float64
#  3   largura_pétala  150 non-null    float64
#  4   tipo_de_iris    150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Vamos analisar nosso conjunto de dados. Use dataset.head (n) para exibir os n dados principais.
# Altere dataset.head (n) para dataset.sample(n) para exibir os dados:
dataset.sample(150)
# Out:
#      altura_sépala  largula_sépala  altura_pétala  largura_pétala  \
# 121            5.6             2.8            4.9             2.0
# 108            6.7             2.5            5.8             1.8
# 144            6.7             3.3            5.7             2.5
# 1              4.9             3.0            1.4             0.2
# 70             5.9             3.2            4.8             1.8
# ..             ...             ...            ...             ...
# 50             7.0             3.2            4.7             1.4
# 78             6.0             2.9            4.5             1.5
# 25             5.0             3.0            1.6             0.2
# 24             4.8             3.4            1.9             0.2
# 80             5.5             2.4            3.8             1.1
#
#         tipo_de_iris
# 121   Iris-virginica
# 108   Iris-virginica
# 144   Iris-virginica
# 1        Iris-setosa
# 70   Iris-versicolor
# ..               ...
# 50   Iris-versicolor
# 78   Iris-versicolor
# 25       Iris-setosa
# 24       Iris-setosa
# 80   Iris-versicolor
#
# [150 rows x 5 columns]

# %%
# Agora que nosso conjunto de dados está pronto, podemos separar os dados de
# entrada (x) e a classe de saída (y). O dado de entrada será uma matriz 150x4 (150 amostras
# com sepal_length, sepal_width, petal_length e petal_width) e a saída 150x1 (iris_class):

# A variável y (saída) será composta somente da classe de saída:
y = dataset['tipo_de_iris']
# Lembramos de remover a saída dos x's de entrada:
x = dataset.drop(['tipo_de_iris'], axis=1)

print ("dataset : ",dataset.shape)
print ("x : ",x.shape)
print ("y : ",y.shape)
# Out:
# dataset :  (150, 5)
# x :  (150, 4)
# y :  (150,)

# %%
# Agora vamos criar nossa rede neural, um Classificador Multi-Layer Perceptron (MLP).
# Precisamos codificar nosso atributo de destino para classificador baseado em Rede Neural
# em um formato adequado. Podemos fazer isso chamando o método get_dummies (y) do Pandas.
# Com este método converteremos a saída para valores "one hot":
# Iris setosa: 100
# Iris versicolor: 010
# Iris virginica: 001
# one hot encoding:
y=pd.get_dummies(y)
# Imprimindo 9 exemplos aleatoriamente, para ver os dados:
y.sample(9)
# Out:
#      Iris-setosa  Iris-versicolor  Iris-virginica
# 131        False            False            True
# 100        False            False            True
# 0           True            False           False
# 17          True            False           False
# 48          True            False           False
# 114        False            False            True
# 74         False             True           False
# 79         False             True           False
# 6           True            False           False

# %%
# Agora que nosso dataset está pronto, temos que separá-lo em conjunto de treinamento e teste.
# Podemos fazer isso usando o método scikit learn train_test_split():

# Importa o train_test_split do Scikit Learn:
from sklearn.model_selection import train_test_split

# Gerando conjunto de treino e teste (30% para teste):
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.15) #0.3 data as data test

# Precisamos converter nosso conjunto de dados para float 32bits, que é o que a MLP recebe:
x_train = np.array(x_train).astype(np.float32)
x_test  = np.array(x_test).astype(np.float32)
y_train = np.array(y_train).astype(np.float32)
y_test  = np.array(y_test).astype(np.float32)

# Vamos imprimir o conjunto de dados para validação:
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (127, 4) (127, 3)
# (23, 4) (23, 3)

# %%
# Nossa rede neural será 4 x 10 x 5 x 3, portanto as camadas ocultas são (10 unidades e 5 unidades).
# Definimos nossa iteração máxima como 5.000 para treinar na época de 5.000 e
# alfa como 0,01 para nossa taxa de aprendizado. Definimos verbose como 1 imprimir as saídas
# durante o processo de treinamento. Random_state é usado como uma semente aleatória:

# Importanto a lib de MLP
from sklearn.neural_network import MLPClassifier

# Initialização do modelo:
Model = MLPClassifier(hidden_layer_sizes=(3,2), max_iter=10000, alpha=0.01, #try change hidden layer
                     solver='sgd', verbose=1,  random_state=233) #try verbode=0 to train with out logging
#train our model
h=Model.fit(x_train,y_train)

#use our model to predict
y_pred=Model.predict(x_test)
# Out:
# Iteration 1, loss = 2.14262370
# Iteration 2, loss = 2.12285986
# Iteration 3, loss = 2.09187053
# Iteration 4, loss = 2.04722519
# Iteration 5, loss = 1.98924988
# Iteration 6, loss = 1.91188547
# Iteration 7, loss = 1.82384511
# Iteration 8, loss = 1.73724593
# Iteration 9, loss = 1.65790221
# Iteration 10, loss = 1.59008587
# Iteration 11, loss = 1.53547883
# Iteration 12, loss = 1.49377335
# Iteration 13, loss = 1.46358856
# Iteration 14, loss = 1.44300764
# Iteration 15, loss = 1.42990452
# Iteration 16, loss = 1.42230047
# Iteration 17, loss = 1.41886533
# Iteration 18, loss = 1.41794399
# Iteration 19, loss = 1.41963783
# Iteration 20, loss = 1.42168915
# Iteration 21, loss = 1.42226365
# Iteration 22, loss = 1.42084933
# Iteration 23, loss = 1.41638386
# Iteration 24, loss = 1.40871814
# Iteration 25, loss = 1.39840958
# Iteration 26, loss = 1.38614800
# Iteration 27, loss = 1.37294806
# Iteration 28, loss = 1.35975989
# Iteration 29, loss = 1.34743134
# Iteration 30, loss = 1.33616782
# Iteration 31, loss = 1.32597100
# Iteration 32, loss = 1.31690699
# Iteration 33, loss = 1.30896136
# Iteration 34, loss = 1.30228969
# Iteration 35, loss = 1.29628996
# Iteration 36, loss = 1.29059707
# Iteration 37, loss = 1.28505849
# Iteration 38, loss = 1.27954638
# Iteration 39, loss = 1.27394701
# Iteration 40, loss = 1.26819155
# Iteration 41, loss = 1.26224559
# Iteration 42, loss = 1.25617649
# Iteration 43, loss = 1.25018438
# Iteration 44, loss = 1.24445582
# Iteration 45, loss = 1.23879868
# Iteration 46, loss = 1.23322116
# Iteration 47, loss = 1.22772062
# Iteration 48, loss = 1.22234987
# Iteration 49, loss = 1.21714435
# Iteration 50, loss = 1.21220103
# Iteration 51, loss = 1.20751816
# Iteration 52, loss = 1.20291492
# Iteration 53, loss = 1.19848429
# Iteration 54, loss = 1.19409942
# Iteration 55, loss = 1.18973952
# Iteration 56, loss = 1.18540334
# Iteration 57, loss = 1.18107896
# Iteration 58, loss = 1.17677277
# Iteration 59, loss = 1.17249107
# Iteration 60, loss = 1.16824414
# Iteration 61, loss = 1.16403805
# Iteration 62, loss = 1.15987729
# Iteration 63, loss = 1.15576468
# Iteration 64, loss = 1.15169784
# Iteration 65, loss = 1.14767680
# Iteration 66, loss = 1.14370056
# Iteration 67, loss = 1.13977025
# Iteration 68, loss = 1.13588580
# Iteration 69, loss = 1.13204112
# Iteration 70, loss = 1.12823527
# Iteration 71, loss = 1.12446792
# Iteration 72, loss = 1.12073907
# Iteration 73, loss = 1.11704917
# Iteration 74, loss = 1.11340183
# Iteration 75, loss = 1.10979914
# Iteration 76, loss = 1.10623880
# Iteration 77, loss = 1.10272040
# Iteration 78, loss = 1.09924464
# Iteration 79, loss = 1.09581194
# Iteration 80, loss = 1.09242244
# Iteration 81, loss = 1.08907560
# Iteration 82, loss = 1.08577106
# Iteration 83, loss = 1.08250935
# Iteration 84, loss = 1.07928895
# Iteration 85, loss = 1.07610879
# Iteration 86, loss = 1.07296808
# Iteration 87, loss = 1.06986594
# Iteration 88, loss = 1.06680168
# Iteration 89, loss = 1.06377459
# Iteration 90, loss = 1.06078443
# Iteration 91, loss = 1.05783048
# Iteration 92, loss = 1.05491225
# Iteration 93, loss = 1.05202959
# Iteration 94, loss = 1.04918219
# Iteration 95, loss = 1.04637018
# Iteration 96, loss = 1.04359288
# Iteration 97, loss = 1.04084962
# Iteration 98, loss = 1.03814008
# Iteration 99, loss = 1.03546398
# Iteration 100, loss = 1.03282101
# Iteration 101, loss = 1.03021071
# Iteration 102, loss = 1.02763274
# Iteration 103, loss = 1.02508682
# Iteration 104, loss = 1.02257253
# Iteration 105, loss = 1.02008993
# Iteration 106, loss = 1.01763869
# Iteration 107, loss = 1.01521835
# Iteration 108, loss = 1.01282835
# Iteration 109, loss = 1.01046845
# Iteration 110, loss = 1.00813812
# Iteration 111, loss = 1.00583714
# Iteration 112, loss = 1.00356513
# Iteration 113, loss = 1.00132154
# Iteration 114, loss = 0.99910658
# Iteration 115, loss = 0.99691968
# Iteration 116, loss = 0.99476027
# Iteration 117, loss = 0.99262811
# Iteration 118, loss = 0.99052273
# Iteration 119, loss = 0.98844405
# Iteration 120, loss = 0.98639191
# Iteration 121, loss = 0.98436567
# Iteration 122, loss = 0.98236592
# Iteration 123, loss = 0.98039163
# Iteration 124, loss = 0.97844216
# Iteration 125, loss = 0.97651727
# Iteration 126, loss = 0.97461658
# Iteration 127, loss = 0.97273988
# Iteration 128, loss = 0.97088677
# Iteration 129, loss = 0.96905690
# Iteration 130, loss = 0.96724996
# Iteration 131, loss = 0.96546573
# Iteration 132, loss = 0.96370426
# Iteration 133, loss = 0.96196514
# Iteration 134, loss = 0.96024787
# Iteration 135, loss = 0.95855193
# Iteration 136, loss = 0.95687718
# Iteration 137, loss = 0.95522313
# Iteration 138, loss = 0.95358966
# Iteration 139, loss = 0.95197636
# Iteration 140, loss = 0.95038291
# Iteration 141, loss = 0.94880909
# Iteration 142, loss = 0.94725452
# Iteration 143, loss = 0.94571903
# Iteration 144, loss = 0.94420221
# Iteration 145, loss = 0.94270384
# Iteration 146, loss = 0.94122360
# Iteration 147, loss = 0.93976135
# Iteration 148, loss = 0.93831671
# Iteration 149, loss = 0.93688941
# Iteration 150, loss = 0.93547917
# Iteration 151, loss = 0.93408577
# Iteration 152, loss = 0.93270898
# Iteration 153, loss = 0.93134839
# Iteration 154, loss = 0.93000391
# Iteration 155, loss = 0.92867527
# Iteration 156, loss = 0.92736209
# Iteration 157, loss = 0.92606431
# Iteration 158, loss = 0.92478161
# Iteration 159, loss = 0.92351373
# Iteration 160, loss = 0.92226052
# Iteration 161, loss = 0.92102159
# Iteration 162, loss = 0.91979683
# Iteration 163, loss = 0.91858601
# Iteration 164, loss = 0.91738897
# Iteration 165, loss = 0.91620534
# Iteration 166, loss = 0.91503500
# Iteration 167, loss = 0.91387768
# Iteration 168, loss = 0.91273322
# Iteration 169, loss = 0.91160144
# Iteration 170, loss = 0.91048202
# Iteration 171, loss = 0.90937485
# Iteration 172, loss = 0.90827977
# Iteration 173, loss = 0.90719649
# Iteration 174, loss = 0.90612487
# Iteration 175, loss = 0.90506463
# Iteration 176, loss = 0.90401573
# Iteration 177, loss = 0.90297796
# Iteration 178, loss = 0.90195098
# Iteration 179, loss = 0.90093475
# Iteration 180, loss = 0.89992908
# Iteration 181, loss = 0.89893381
# Iteration 182, loss = 0.89794890
# Iteration 183, loss = 0.89697444
# Iteration 184, loss = 0.89600989
# Iteration 185, loss = 0.89505511
# Iteration 186, loss = 0.89411006
# Iteration 187, loss = 0.89317449
# Iteration 188, loss = 0.89224812
# Iteration 189, loss = 0.89133083
# Iteration 190, loss = 0.89042252
# Iteration 191, loss = 0.88952298
# Iteration 192, loss = 0.88863209
# Iteration 193, loss = 0.88774973
# Iteration 194, loss = 0.88687564
# Iteration 195, loss = 0.88600977
# Iteration 196, loss = 0.88515196
# Iteration 197, loss = 0.88430202
# Iteration 198, loss = 0.88345987
# Iteration 199, loss = 0.88262531
# Iteration 200, loss = 0.88179838
# Iteration 201, loss = 0.88097874
# Iteration 202, loss = 0.88016640
# Iteration 203, loss = 0.87936118
# Iteration 204, loss = 0.87856303
# Iteration 205, loss = 0.87777175
# Iteration 206, loss = 0.87698727
# Iteration 207, loss = 0.87620947
# Iteration 208, loss = 0.87543819
# Iteration 209, loss = 0.87467346
# Iteration 210, loss = 0.87391492
# Iteration 211, loss = 0.87316271
# Iteration 212, loss = 0.87241662
# Iteration 213, loss = 0.87167646
# Iteration 214, loss = 0.87094237
# Iteration 215, loss = 0.87021398
# Iteration 216, loss = 0.86949140
# Iteration 217, loss = 0.86877445
# Iteration 218, loss = 0.86806300
# Iteration 219, loss = 0.86735701
# Iteration 220, loss = 0.86665634
# Iteration 221, loss = 0.86596094
# Iteration 222, loss = 0.86527077
# Iteration 223, loss = 0.86458573
# Iteration 224, loss = 0.86390563
# Iteration 225, loss = 0.86323050
# Iteration 226, loss = 0.86256025
# Iteration 227, loss = 0.86189472
# Iteration 228, loss = 0.86123395
# Iteration 229, loss = 0.86057776
# Iteration 230, loss = 0.85992612
# Iteration 231, loss = 0.85927901
# Iteration 232, loss = 0.85863628
# Iteration 233, loss = 0.85799791
# Iteration 234, loss = 0.85736377
# Iteration 235, loss = 0.85673387
# Iteration 236, loss = 0.85610805
# Iteration 237, loss = 0.85548638
# Iteration 238, loss = 0.85486868
# Iteration 239, loss = 0.85425496
# Iteration 240, loss = 0.85364513
# Iteration 241, loss = 0.85303914
# Iteration 242, loss = 0.85243692
# Iteration 243, loss = 0.85183843
# Iteration 244, loss = 0.85124357
# Iteration 245, loss = 0.85065236
# Iteration 246, loss = 0.85006470
# Iteration 247, loss = 0.84948052
# Iteration 248, loss = 0.84889984
# Iteration 249, loss = 0.84832254
# Iteration 250, loss = 0.84774862
# Iteration 251, loss = 0.84717798
# Iteration 252, loss = 0.84661061
# Iteration 253, loss = 0.84604648
# Iteration 254, loss = 0.84548554
# Iteration 255, loss = 0.84492765
# Iteration 256, loss = 0.84437291
# Iteration 257, loss = 0.84382119
# Iteration 258, loss = 0.84327249
# Iteration 259, loss = 0.84272678
# Iteration 260, loss = 0.84218388
# Iteration 261, loss = 0.84164407
# Iteration 262, loss = 0.84110716
# Iteration 263, loss = 0.84057313
# Iteration 264, loss = 0.84004178
# Iteration 265, loss = 0.83951330
# Iteration 266, loss = 0.83898746
# Iteration 267, loss = 0.83846432
# Iteration 268, loss = 0.83794382
# Iteration 269, loss = 0.83742589
# Iteration 270, loss = 0.83691060
# Iteration 271, loss = 0.83639779
# Iteration 272, loss = 0.83588758
# Iteration 273, loss = 0.83537978
# Iteration 274, loss = 0.83487443
# Iteration 275, loss = 0.83437160
# Iteration 276, loss = 0.83387110
# Iteration 277, loss = 0.83337298
# Iteration 278, loss = 0.83287722
# Iteration 279, loss = 0.83238379
# Iteration 280, loss = 0.83189264
# Iteration 281, loss = 0.83140375
# Iteration 282, loss = 0.83091712
# Iteration 283, loss = 0.83043268
# Iteration 284, loss = 0.82995043
# Iteration 285, loss = 0.82947034
# Iteration 286, loss = 0.82899247
# Iteration 287, loss = 0.82851671
# Iteration 288, loss = 0.82804304
# Iteration 289, loss = 0.82757143
# Iteration 290, loss = 0.82710190
# Iteration 291, loss = 0.82663438
# Iteration 292, loss = 0.82616897
# Iteration 293, loss = 0.82570548
# Iteration 294, loss = 0.82524401
# Iteration 295, loss = 0.82478449
# Iteration 296, loss = 0.82432693
# Iteration 297, loss = 0.82387135
# Iteration 298, loss = 0.82341760
# Iteration 299, loss = 0.82296583
# Iteration 300, loss = 0.82251582
# Iteration 301, loss = 0.82206777
# Iteration 302, loss = 0.82162155
# Iteration 303, loss = 0.82117717
# Iteration 304, loss = 0.82073460
# Iteration 305, loss = 0.82029380
# Iteration 306, loss = 0.81985482
# Iteration 307, loss = 0.81941762
# Iteration 308, loss = 0.81898213
# Iteration 309, loss = 0.81854839
# Iteration 310, loss = 0.81811641
# Iteration 311, loss = 0.81768611
# Iteration 312, loss = 0.81725754
# Iteration 313, loss = 0.81683059
# Iteration 314, loss = 0.81640536
# Iteration 315, loss = 0.81598180
# Iteration 316, loss = 0.81555990
# Iteration 317, loss = 0.81513965
# Iteration 318, loss = 0.81472101
# Iteration 319, loss = 0.81430397
# Iteration 320, loss = 0.81388855
# Iteration 321, loss = 0.81347473
# Iteration 322, loss = 0.81306250
# Iteration 323, loss = 0.81265182
# Iteration 324, loss = 0.81224269
# Iteration 325, loss = 0.81183514
# Iteration 326, loss = 0.81142911
# Iteration 327, loss = 0.81102456
# Iteration 328, loss = 0.81062158
# Iteration 329, loss = 0.81022010
# Iteration 330, loss = 0.80982013
# Iteration 331, loss = 0.80942162
# Iteration 332, loss = 0.80902465
# Iteration 333, loss = 0.80862910
# Iteration 334, loss = 0.80823500
# Iteration 335, loss = 0.80784242
# Iteration 336, loss = 0.80745123
# Iteration 337, loss = 0.80706149
# Iteration 338, loss = 0.80667317
# Iteration 339, loss = 0.80628627
# Iteration 340, loss = 0.80590088
# Iteration 341, loss = 0.80551676
# Iteration 342, loss = 0.80513408
# Iteration 343, loss = 0.80475282
# Iteration 344, loss = 0.80437288
# Iteration 345, loss = 0.80399434
# Iteration 346, loss = 0.80361712
# Iteration 347, loss = 0.80324134
# Iteration 348, loss = 0.80286690
# Iteration 349, loss = 0.80249373
# Iteration 350, loss = 0.80212194
# Iteration 351, loss = 0.80175149
# Iteration 352, loss = 0.80138237
# Iteration 353, loss = 0.80101452
# Iteration 354, loss = 0.80064800
# Iteration 355, loss = 0.80028282
# Iteration 356, loss = 0.79991884
# Iteration 357, loss = 0.79955622
# Iteration 358, loss = 0.79919487
# Iteration 359, loss = 0.79883477
# Iteration 360, loss = 0.79847599
# Iteration 361, loss = 0.79811845
# Iteration 362, loss = 0.79776212
# Iteration 363, loss = 0.79740708
# Iteration 364, loss = 0.79705331
# Iteration 365, loss = 0.79670071
# Iteration 366, loss = 0.79634946
# Iteration 367, loss = 0.79599937
# Iteration 368, loss = 0.79565045
# Iteration 369, loss = 0.79530274
# Iteration 370, loss = 0.79495635
# Iteration 371, loss = 0.79461111
# Iteration 372, loss = 0.79426706
# Iteration 373, loss = 0.79392418
# Iteration 374, loss = 0.79358255
# Iteration 375, loss = 0.79324201
# Iteration 376, loss = 0.79290270
# Iteration 377, loss = 0.79256460
# Iteration 378, loss = 0.79222759
# Iteration 379, loss = 0.79189178
# Iteration 380, loss = 0.79155714
# Iteration 381, loss = 0.79122364
# Iteration 382, loss = 0.79089130
# Iteration 383, loss = 0.79056006
# Iteration 384, loss = 0.79023001
# Iteration 385, loss = 0.78990102
# Iteration 386, loss = 0.78957319
# Iteration 387, loss = 0.78924650
# Iteration 388, loss = 0.78892092
# Iteration 389, loss = 0.78859642
# Iteration 390, loss = 0.78827308
# Iteration 391, loss = 0.78795079
# Iteration 392, loss = 0.78762963
# Iteration 393, loss = 0.78730954
# Iteration 394, loss = 0.78699053
# Iteration 395, loss = 0.78667270
# Iteration 396, loss = 0.78635582
# Iteration 397, loss = 0.78604012
# Iteration 398, loss = 0.78572539
# Iteration 399, loss = 0.78541180
# Iteration 400, loss = 0.78509923
# Iteration 401, loss = 0.78478776
# Iteration 402, loss = 0.78447732
# Iteration 403, loss = 0.78416801
# Iteration 404, loss = 0.78385973
# Iteration 405, loss = 0.78355251
# Iteration 406, loss = 0.78324629
# Iteration 407, loss = 0.78294115
# Iteration 408, loss = 0.78263701
# Iteration 409, loss = 0.78233387
# Iteration 410, loss = 0.78203180
# Iteration 411, loss = 0.78173069
# Iteration 412, loss = 0.78143065
# Iteration 413, loss = 0.78113162
# Iteration 414, loss = 0.78083356
# Iteration 415, loss = 0.78053652
# Iteration 416, loss = 0.78024054
# Iteration 417, loss = 0.77994554
# Iteration 418, loss = 0.77965156
# Iteration 419, loss = 0.77935848
# Iteration 420, loss = 0.77906650
# Iteration 421, loss = 0.77877545
# Iteration 422, loss = 0.77848530
# Iteration 423, loss = 0.77819628
# Iteration 424, loss = 0.77790813
# Iteration 425, loss = 0.77762098
# Iteration 426, loss = 0.77733480
# Iteration 427, loss = 0.77704959
# Iteration 428, loss = 0.77676530
# Iteration 429, loss = 0.77648197
# Iteration 430, loss = 0.77619961
# Iteration 431, loss = 0.77591813
# Iteration 432, loss = 0.77563763
# Iteration 433, loss = 0.77535803
# Iteration 434, loss = 0.77507942
# Iteration 435, loss = 0.77480162
# Iteration 436, loss = 0.77452484
# Iteration 437, loss = 0.77424891
# Iteration 438, loss = 0.77397390
# Iteration 439, loss = 0.77369987
# Iteration 440, loss = 0.77342672
# Iteration 441, loss = 0.77315441
# Iteration 442, loss = 0.77288303
# Iteration 443, loss = 0.77261255
# Iteration 444, loss = 0.77234296
# Iteration 445, loss = 0.77207428
# Iteration 446, loss = 0.77180641
# Iteration 447, loss = 0.77153944
# Iteration 448, loss = 0.77127338
# Iteration 449, loss = 0.77100816
# Iteration 450, loss = 0.77074388
# Iteration 451, loss = 0.77048044
# Iteration 452, loss = 0.77021777
# Iteration 453, loss = 0.76995607
# Iteration 454, loss = 0.76969522
# Iteration 455, loss = 0.76943516
# Iteration 456, loss = 0.76917598
# Iteration 457, loss = 0.76891765
# Iteration 458, loss = 0.76866020
# Iteration 459, loss = 0.76840352
# Iteration 460, loss = 0.76814770
# Iteration 461, loss = 0.76789273
# Iteration 462, loss = 0.76763859
# Iteration 463, loss = 0.76738528
# Iteration 464, loss = 0.76713273
# Iteration 465, loss = 0.76688104
# Iteration 466, loss = 0.76663024
# Iteration 467, loss = 0.76638015
# Iteration 468, loss = 0.76613096
# Iteration 469, loss = 0.76588251
# Iteration 470, loss = 0.76563491
# Iteration 471, loss = 0.76538812
# Iteration 472, loss = 0.76514207
# Iteration 473, loss = 0.76489688
# Iteration 474, loss = 0.76465241
# Iteration 475, loss = 0.76440875
# Iteration 476, loss = 0.76416591
# Iteration 477, loss = 0.76392382
# Iteration 478, loss = 0.76368253
# Iteration 479, loss = 0.76344203
# Iteration 480, loss = 0.76320225
# Iteration 481, loss = 0.76296331
# Iteration 482, loss = 0.76272513
# Iteration 483, loss = 0.76248771
# Iteration 484, loss = 0.76225104
# Iteration 485, loss = 0.76201516
# Iteration 486, loss = 0.76178007
# Iteration 487, loss = 0.76154573
# Iteration 488, loss = 0.76131219
# Iteration 489, loss = 0.76107941
# Iteration 490, loss = 0.76084737
# Iteration 491, loss = 0.76061606
# Iteration 492, loss = 0.76038550
# Iteration 493, loss = 0.76015566
# Iteration 494, loss = 0.75992658
# Iteration 495, loss = 0.75969827
# Iteration 496, loss = 0.75947064
# Iteration 497, loss = 0.75924375
# Iteration 498, loss = 0.75901763
# Iteration 499, loss = 0.75879219
# Iteration 500, loss = 0.75856747
# Iteration 501, loss = 0.75834345
# Iteration 502, loss = 0.75812017
# Iteration 503, loss = 0.75789763
# Iteration 504, loss = 0.75767575
# Iteration 505, loss = 0.75745461
# Iteration 506, loss = 0.75723416
# Iteration 507, loss = 0.75701441
# Iteration 508, loss = 0.75679534
# Iteration 509, loss = 0.75657698
# Iteration 510, loss = 0.75635935
# Iteration 511, loss = 0.75614236
# Iteration 512, loss = 0.75592609
# Iteration 513, loss = 0.75571050
# Iteration 514, loss = 0.75549559
# Iteration 515, loss = 0.75528136
# Iteration 516, loss = 0.75506785
# Iteration 517, loss = 0.75485494
# Iteration 518, loss = 0.75464272
# Iteration 519, loss = 0.75443118
# Iteration 520, loss = 0.75422031
# Iteration 521, loss = 0.75401010
# Iteration 522, loss = 0.75380052
# Iteration 523, loss = 0.75359168
# Iteration 524, loss = 0.75338347
# Iteration 525, loss = 0.75317584
# Iteration 526, loss = 0.75296894
# Iteration 527, loss = 0.75276267
# Iteration 528, loss = 0.75255706
# Iteration 529, loss = 0.75235211
# Iteration 530, loss = 0.75214772
# Iteration 531, loss = 0.75194404
# Iteration 532, loss = 0.75174098
# Iteration 533, loss = 0.75153857
# Iteration 534, loss = 0.75133677
# Iteration 535, loss = 0.75113560
# Iteration 536, loss = 0.75093510
# Iteration 537, loss = 0.75073518
# Iteration 538, loss = 0.75053591
# Iteration 539, loss = 0.75033731
# Iteration 540, loss = 0.75013922
# Iteration 541, loss = 0.74994179
# Iteration 542, loss = 0.74974503
# Iteration 543, loss = 0.74954882
# Iteration 544, loss = 0.74935326
# Iteration 545, loss = 0.74915831
# Iteration 546, loss = 0.74896397
# Iteration 547, loss = 0.74877020
# Iteration 548, loss = 0.74857706
# Iteration 549, loss = 0.74838453
# Iteration 550, loss = 0.74819253
# Iteration 551, loss = 0.74800120
# Iteration 552, loss = 0.74781039
# Iteration 553, loss = 0.74762026
# Iteration 554, loss = 0.74743068
# Iteration 555, loss = 0.74724168
# Iteration 556, loss = 0.74705326
# Iteration 557, loss = 0.74686544
# Iteration 558, loss = 0.74667821
# Iteration 559, loss = 0.74649153
# Iteration 560, loss = 0.74630538
# Iteration 561, loss = 0.74611990
# Iteration 562, loss = 0.74593492
# Iteration 563, loss = 0.74575054
# Iteration 564, loss = 0.74556676
# Iteration 565, loss = 0.74538351
# Iteration 566, loss = 0.74520086
# Iteration 567, loss = 0.74501866
# Iteration 568, loss = 0.74483714
# Iteration 569, loss = 0.74465616
# Iteration 570, loss = 0.74447570
# Iteration 571, loss = 0.74429585
# Iteration 572, loss = 0.74411648
# Iteration 573, loss = 0.74393767
# Iteration 574, loss = 0.74375942
# Iteration 575, loss = 0.74358171
# Iteration 576, loss = 0.74340459
# Iteration 577, loss = 0.74322803
# Iteration 578, loss = 0.74305188
# Iteration 579, loss = 0.74287638
# Iteration 580, loss = 0.74270135
# Iteration 581, loss = 0.74252690
# Iteration 582, loss = 0.74235301
# Iteration 583, loss = 0.74217961
# Iteration 584, loss = 0.74200674
# Iteration 585, loss = 0.74183438
# Iteration 586, loss = 0.74166255
# Iteration 587, loss = 0.74149129
# Iteration 588, loss = 0.74132051
# Iteration 589, loss = 0.74115020
# Iteration 590, loss = 0.74098046
# Iteration 591, loss = 0.74081124
# Iteration 592, loss = 0.74064255
# Iteration 593, loss = 0.74047436
# Iteration 594, loss = 0.74030668
# Iteration 595, loss = 0.74013944
# Iteration 596, loss = 0.73997279
# Iteration 597, loss = 0.73980661
# Iteration 598, loss = 0.73964096
# Iteration 599, loss = 0.73947576
# Iteration 600, loss = 0.73931107
# Iteration 601, loss = 0.73914693
# Iteration 602, loss = 0.73898323
# Iteration 603, loss = 0.73882006
# Iteration 604, loss = 0.73865734
# Iteration 605, loss = 0.73849517
# Iteration 606, loss = 0.73833344
# Iteration 607, loss = 0.73817223
# Iteration 608, loss = 0.73801144
# Iteration 609, loss = 0.73785121
# Iteration 610, loss = 0.73769141
# Iteration 611, loss = 0.73753211
# Iteration 612, loss = 0.73737331
# Iteration 613, loss = 0.73721497
# Iteration 614, loss = 0.73705706
# Iteration 615, loss = 0.73689962
# Iteration 616, loss = 0.73674275
# Iteration 617, loss = 0.73658627
# Iteration 618, loss = 0.73643035
# Iteration 619, loss = 0.73627487
# Iteration 620, loss = 0.73611986
# Iteration 621, loss = 0.73596532
# Iteration 622, loss = 0.73581122
# Iteration 623, loss = 0.73565762
# Iteration 624, loss = 0.73550447
# Iteration 625, loss = 0.73535178
# Iteration 626, loss = 0.73519955
# Iteration 627, loss = 0.73504779
# Iteration 628, loss = 0.73489647
# Iteration 629, loss = 0.73474563
# Iteration 630, loss = 0.73459523
# Iteration 631, loss = 0.73444525
# Iteration 632, loss = 0.73429582
# Iteration 633, loss = 0.73414681
# Iteration 634, loss = 0.73399823
# Iteration 635, loss = 0.73385012
# Iteration 636, loss = 0.73370241
# Iteration 637, loss = 0.73355519
# Iteration 638, loss = 0.73340835
# Iteration 639, loss = 0.73326200
# Iteration 640, loss = 0.73311605
# Iteration 641, loss = 0.73297058
# Iteration 642, loss = 0.73282548
# Iteration 643, loss = 0.73268083
# Iteration 644, loss = 0.73253662
# Iteration 645, loss = 0.73239284
# Iteration 646, loss = 0.73224945
# Iteration 647, loss = 0.73210654
# Iteration 648, loss = 0.73196399
# Iteration 649, loss = 0.73182191
# Iteration 650, loss = 0.73168019
# Iteration 651, loss = 0.73153894
# Iteration 652, loss = 0.73139810
# Iteration 653, loss = 0.73125764
# Iteration 654, loss = 0.73111763
# Iteration 655, loss = 0.73097799
# Iteration 656, loss = 0.73083875
# Iteration 657, loss = 0.73069998
# Iteration 658, loss = 0.73056161
# Iteration 659, loss = 0.73042359
# Iteration 660, loss = 0.73028602
# Iteration 661, loss = 0.73014884
# Iteration 662, loss = 0.73001202
# Iteration 663, loss = 0.72987565
# Iteration 664, loss = 0.72973967
# Iteration 665, loss = 0.72960404
# Iteration 666, loss = 0.72946883
# Iteration 667, loss = 0.72933407
# Iteration 668, loss = 0.72919963
# Iteration 669, loss = 0.72906562
# Iteration 670, loss = 0.72893194
# Iteration 671, loss = 0.72879878
# Iteration 672, loss = 0.72866585
# Iteration 673, loss = 0.72853340
# Iteration 674, loss = 0.72840131
# Iteration 675, loss = 0.72826963
# Iteration 676, loss = 0.72813825
# Iteration 677, loss = 0.72800732
# Iteration 678, loss = 0.72787672
# Iteration 679, loss = 0.72774654
# Iteration 680, loss = 0.72761677
# Iteration 681, loss = 0.72748727
# Iteration 682, loss = 0.72735818
# Iteration 683, loss = 0.72722950
# Iteration 684, loss = 0.72710115
# Iteration 685, loss = 0.72697319
# Iteration 686, loss = 0.72684564
# Iteration 687, loss = 0.72671838
# Iteration 688, loss = 0.72659148
# Iteration 689, loss = 0.72646502
# Iteration 690, loss = 0.72633889
# Iteration 691, loss = 0.72621311
# Iteration 692, loss = 0.72608770
# Iteration 693, loss = 0.72596262
# Iteration 694, loss = 0.72583789
# Iteration 695, loss = 0.72571357
# Iteration 696, loss = 0.72558958
# Iteration 697, loss = 0.72546596
# Iteration 698, loss = 0.72534269
# Iteration 699, loss = 0.72521975
# Iteration 700, loss = 0.72509720
# Iteration 701, loss = 0.72497494
# Iteration 702, loss = 0.72485305
# Iteration 703, loss = 0.72473156
# Iteration 704, loss = 0.72461036
# Iteration 705, loss = 0.72448950
# Iteration 706, loss = 0.72436899
# Iteration 707, loss = 0.72424883
# Iteration 708, loss = 0.72412897
# Iteration 709, loss = 0.72400953
# Iteration 710, loss = 0.72389039
# Iteration 711, loss = 0.72377158
# Iteration 712, loss = 0.72365308
# Iteration 713, loss = 0.72353496
# Iteration 714, loss = 0.72341712
# Iteration 715, loss = 0.72329969
# Iteration 716, loss = 0.72318254
# Iteration 717, loss = 0.72306576
# Iteration 718, loss = 0.72294926
# Iteration 719, loss = 0.72283310
# Iteration 720, loss = 0.72271727
# Iteration 721, loss = 0.72260177
# Iteration 722, loss = 0.72248658
# Iteration 723, loss = 0.72237172
# Iteration 724, loss = 0.72225720
# Iteration 725, loss = 0.72214299
# Iteration 726, loss = 0.72202904
# Iteration 727, loss = 0.72191550
# Iteration 728, loss = 0.72180221
# Iteration 729, loss = 0.72168930
# Iteration 730, loss = 0.72157663
# Iteration 731, loss = 0.72146433
# Iteration 732, loss = 0.72135233
# Iteration 733, loss = 0.72124067
# Iteration 734, loss = 0.72112928
# Iteration 735, loss = 0.72101816
# Iteration 736, loss = 0.72090745
# Iteration 737, loss = 0.72079706
# Iteration 738, loss = 0.72068691
# Iteration 739, loss = 0.72057702
# Iteration 740, loss = 0.72046749
# Iteration 741, loss = 0.72035826
# Iteration 742, loss = 0.72024934
# Iteration 743, loss = 0.72014072
# Iteration 744, loss = 0.72003242
# Iteration 745, loss = 0.71992437
# Iteration 746, loss = 0.71981662
# Iteration 747, loss = 0.71970919
# Iteration 748, loss = 0.71960208
# Iteration 749, loss = 0.71949523
# Iteration 750, loss = 0.71938869
# Iteration 751, loss = 0.71928242
# Iteration 752, loss = 0.71917650
# Iteration 753, loss = 0.71907084
# Iteration 754, loss = 0.71896542
# Iteration 755, loss = 0.71886035
# Iteration 756, loss = 0.71875552
# Iteration 757, loss = 0.71865102
# Iteration 758, loss = 0.71854682
# Iteration 759, loss = 0.71844286
# Iteration 760, loss = 0.71833915
# Iteration 761, loss = 0.71823585
# Iteration 762, loss = 0.71813272
# Iteration 763, loss = 0.71802992
# Iteration 764, loss = 0.71792740
# Iteration 765, loss = 0.71782511
# Iteration 766, loss = 0.71772318
# Iteration 767, loss = 0.71762149
# Iteration 768, loss = 0.71752004
# Iteration 769, loss = 0.71741891
# Iteration 770, loss = 0.71731804
# Iteration 771, loss = 0.71721740
# Iteration 772, loss = 0.71711712
# Iteration 773, loss = 0.71701704
# Iteration 774, loss = 0.71691726
# Iteration 775, loss = 0.71681775
# Iteration 776, loss = 0.71671849
# Iteration 777, loss = 0.71661957
# Iteration 778, loss = 0.71652087
# Iteration 779, loss = 0.71642240
# Iteration 780, loss = 0.71632424
# Iteration 781, loss = 0.71622632
# Iteration 782, loss = 0.71612869
# Iteration 783, loss = 0.71603130
# Iteration 784, loss = 0.71593418
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
# Depois de terminar o processo de treinamento, podemos usar nosso modelo treinado
# com o método model.predict(). Para obter o nosso resultado de classificação, podemos
# importar classification_report de sklearn.matrix e chamar
# classification_report( "saída correta, predição" ). Para mostrar os resultados
# na matriz de confusão e precisão, também precisamos importá-los de sklearn.matrix:

from sklearn.metrics import mean_squared_error
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# Imprime relatório de performance:
print(classification_report(y_test,y_pred))
# Imprime a matriz de confusão (Confusion matrix):
print(confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1)))
# Imprime a taxa de acerto:
print('accuracy is ',accuracy_score(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       0.00      0.00      0.00         7
#            2       1.00      1.00      1.00        10
#
#    micro avg       0.94      0.70      0.80        23
#    macro avg       0.67      0.67      0.67        23
# weighted avg       0.70      0.70      0.70        23
#  samples avg       0.67      0.70      0.68        23
#
# [[6 0 0]
#  [7 0 0]
#  [0 1 9]]
# accuracy is  0.6521739130434783
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Se quisermos mostrar nosso histórico de loss do modelo,
# podemos representar graficamente a propriedade loss_curve_ de nosso modelo treinado:

import matplotlib.pyplot as plt

plt.plot(h.loss_curve_)
plt.title('Loss History')
plt.xlabel('epoch')
plt.legend(['Loss'])

# %%
# Lembrando de como codificamos nossas saídas:

# Iris setosa: 100
Iris_setosa = np.array( [[1,0,0]] )
# Iris versicolor: 010
Iris_versicolor = np.array( [[0,1,0]] )
# Iris virginica: 001
Iris_virginica  = np.array( [[0,0,1]] )

# Agora podemos fazer previsões com o nosso modelo:
entrada_exemplo = np.array([[5.4,3.7,1.5,0.2]])

y_previsto = Model.predict(entrada_exemplo)

# Caso a saída seja Iris setosa (100):
if np.array_equal(y_previsto, Iris_setosa) == True:
  print('Iris setosa')

# Caso a saída seja Iris versicolor (010):
if np.array_equal(y_previsto, Iris_versicolor) == True:
  print('Iris versicolor')

# Caso a saída seja Iris virginica (001):
if np.array_equal(y_previsto, Iris_virginica) == True:
  print('Iris virginica')
# Out:
# Iris setosa
